# %%
import pandas as pd
import datetime
import re

# %%
## Fix the structure of the `transcripts` datasets like the first ones

# Read the text file
with open('Dataset/transcripts/Episode-5.txt', 'r') as f:
    text = f.read()

# Remove any line breaks within a single sentence
text = re.sub(r'(?<=[a-z]),?-?\n(?=[a-z])', ' ', text, flags=re.IGNORECASE)
print(text)
# Split the text into lines based on the end of a sentence
lines = re.split(r'(?<=[.!?]) +(?=[A-Z])', text)

# Preprocess the transcript data
output_lines = []
for line in lines:
    if re.match(r'^\d+\.\d+', line) and output_lines:
        output_lines.append('\n' + line)
    else:
        output_lines.append(line)

# Update the original text file with the preprocessed data
with open('Dataset/transcripts/Episode-5.txt', 'w') as f:
    f.write('\n'.join(output_lines))
# Out:
# 0.0 ANDREW HUBERMAN: Welcome to the Huberman Lab podcast,
# 2.25 where we discuss science and science-based tools
# 4.92 for everyday life.
# 5.7 [MUSIC PLAYING]
# 9.07 I'm Andrew Huberman,
# and I'm a professor
# 10.93 of neurobiology and ophthalmology
# 12.94 at Stanford School of Medicine.
# 14.41 Today we are discussing fertility.
# 16.57 We will discuss male fertility and female fertility.
# 19.97 And I should mention that today's discussion is not just
# 23.14 for people who are seeking to conceive children
# 25.45 or who want to know how their children were conceived,
# 27.79 but it's really for everybody.
# 29.47 And I say that because it is the story of all of us.
# 32.95 All of us are here because a specialized set
# 35.8 of cells, called germ cells--
# 38.2 that is the sperm and the egg.
# 39.853 And I'll make it very clear why they're called
# 41.77 germ cells a little bit later.
# 43.02 It has nothing to do with infection.
# 44.62 But it's because a sperm cell and an egg cell arrived at one
# 50.29 another, either in vivo-- inside of our mother-- or in vitro--
# 54.138 so-called in vitro fertilization-- and then
# 55.93 we're implanted into our mother and became us.
# 59.59 And so understanding the process of how
# 62.8 the egg cell and the sperm cell came to be
# 66.13 is really the key to understanding
# 67.93 how that fertilization process came to be.
# 70.263 Now, I know everyone's thinking, I
# 71.68 know how fertilization occurs.
# 73.202 It occurs through sexual intercourse and so on.
# 75.16 And we'll talk a little bit about that.
# 77.05 But I promise you that if you understand
# 79.75 the menstrual cycle--
# 81.28 and the menstrual cycle in today's conversation
# 83.83 can best be thought of as a biological cycle that
# 86.95 occurs in females that allows the potential for fertilization
# 90.94 by the sperm, because that's really what it is,
# 93.04 and it's a beautifully orchestrated process
# 95.08 that I'll describe to you.
# 96.22 And I should say, all people,
# males and females, should
# 99.79 really understand how the menstrual cycle works,
# 101.95 how it impacts fertilization, but also
# 105.43 how it impacts the brain and body, behavior, psychology,
# 108.46 et cetera.
# 109.12 And we'll also talk about spermatogenesis,
# 112.45 how sperm cells come to be and how they arrive--
# 116.74 that is, how they swim to the egg--
# 118.45 and the incredible interplay between the biology
# 121.81 of the sperm and the biology of the egg
# 125.47 leads to this incredible thing that we call embryogenesis
# 128.77 and the birth of the child and, of course,
# 131.93 the development of that child into an infant, a toddler,
# 136.21 an adolescent, a teen, and an adult.
# 139.6 Today's discussion,
# again, is not just
# 141.79 for those of you that are seeking to have children.
# 144.55 And I say that because when you look at the data,
# 148.42 you look at the literature on longevity and vitality,
# 151.87 two themes in biology that oftentimes people lump together
# 155.55 but aren't always the same-- for instance,
# 157.3 there are a lot of things that we
# 158.675 can do to increase our vitality that actually
# 161.17 can harm our longevity.
# 163.45 But there are a subset of biological rules and mechanisms
# 167.86 that, when aligned,
# allow us to maximize both
# 171.1 our vitality and our longevity.
# 174.14 And I think it's fair to say that all of those mechanisms
# 177.43 and tools are housed in the discussion
# 179.65 around maximizing fertility.
# 181.942 And that's true whether or not you're male or female.
# 184.15 In other words, if you want children
# 186.22 or if you don't, if you already have children
# 188.26 or if you don't, understanding how fertility and fertilization
# 192.85 occurs in the brain and body will
# 195.67 allow you to maximize your vitality and longevity.
# 198.76 And of course,
# today's discussion
# 200.26 will provide an understanding of the biology
# 202.63 and many actionable tools that will also help you conceive
# 205.42 children, if that's your wish.
# 206.98 So of course, as is characteristic of this podcast,
# 210.02 we will discuss science-based tools,
# 212.18 including behavioral tools, both the dos and the don'ts, and we
# 215.86 will discuss nutrition-based tools and supplementation-based
# 219.25 tools and some other practices,
# including things like
# 222.55 acupuncture, which have quite good data to support them
# 226.09 in terms of improving fertility.
# 227.8 And we will discuss why those certain practices can work.
# 231.76 And we will discuss prescription drugs
# 233.89 that your doctor can prescribe to you if, for instance, you
# 237.82 have a deficit at the level of hormone production
# 240.107 or neurotransmitter production at the level of the brain
# 242.44 or the pituitary gland--
# 243.52 I'll explain what all of those things are soon--
# 245.74 or the gonads, the ovary and the testes in females and males
# 250.03 respectively.
# 252.08 Again, by the end of today's episode,
# 253.64 you will have a lot of knowledge and actionable tools related
# 256.39 to maximizing fertility, and you will
# 258.85 have a lot of knowledge and actionable tools related
# 261.49 to maximizing vitality and longevity.
# 264.76 Before we begin, I'd like to emphasize
# 266.532 that this podcast is separate from my teaching and research
# 268.99 roles at Stanford.
# 270.07 It is, however, part of my desire and effort
# 272.29 to bring zero cost to consumer information
# 274.24 about science and science-related tools
# 276.1 to the general public.
# 277.45 In keeping with that theme, I'd like
# 278.95 to thank the sponsors of today's podcast.
# 281.42 Our first sponsor is Maui Nui Meats.
# 283.69 Maui Nui Meats, I can confidently say,
# 285.82 are the most nutrient-dense and delicious red meat available.
# 288.97 Maui Nui he spent nearly a decade
# 290.77 building a USDA-certified wild harvesting system
# 294.1 to help balance invasive deer populations
# 296.29 on the island of Maui.
# 297.76 The solution they built turns the proliferation
# 299.86 of an invasive species into a wide range
# 302.14 of nutrient-dense products, from fresh butcher cuts and organ
# 305.17 meats to bone broth,
# jerky, and even pet treats.
# 308.22 Their bone broth has an unmatched 25 grams
# 310.59 of protein per 100 calories.
# 312.563 I've talked before on this podcast
# 313.98 and I've had several expert guests come on this podcast
# 316.5 to talk about the fact that most people should aim
# 319.32 to get 1 gram of quality protein per pound
# 322.47 of body weight per day in order to maximize
# 324.78 their health, tissue repair,
# which includes brain tissue
# 327.45 repair, and, if you're an active exerciser, to support recovery
# 331.23 from exercise.
# 332.82 Maui Nui Meats have an incredible quality protein
# 336.09 to calorie ratio.
# 337.35 And I mentioned the bone broth.
# 339.13 I should also mention that their ground meats and their venison
# 341.82 steaks are absolutely delicious, and their jerky
# 344.13 is absolutely terrific.
# 345.12 In fact, it's the only jerky that I've eaten consistently
# 347.7 that I happen to like consistently over time.
# 349.95 If you'd like to try Maui Nui Venison,
# 352.02 go to mauinuivenison.com/huberman
# 355.5 to get 20% off your first order.
# 357.18 Again, that's mauinuivenison.com/huberman
# 360.3 to get 20% off your first order.
# 362.4 Today's episode is also brought to us by Eight Sleep.
# 365.13 Eight Sleep makes smart mattress covers with cooling, heating,
# 367.83 and sleep tracking capacity.
# 369.63 I've talked many times before on this podcast
# 371.73 about the fact that sleep is the fundamental layer
# 374.34 of mental health, physical health, and performance.
# 376.57 Now, one of the key things for getting a great night's sleep
# 379.07 every single night is to optimize the temperature
# 381.48 of your sleeping environment.
# 382.95 Put simply, in order to fall asleep and stay deeply asleep,
# 386.37 your body temperature needs to drop by about 1 to 3 degrees.
# 389.34 And waking up, on the other hand,
# 391.12 involves a heating of your body by about 1 to 3 degrees.
# 394.59 With Eight Sleep, you can tune the temperature
# 397.47 of your mattress cover or mattress
# 399.51 to be cooler or hotter, depending on
# 401.855 whether or not you tend to run too hot or too cold,
# 403.98 and you can even vary it across the night
# 405.78 so that you can access the best deep sleep early
# 408.0 in the night, the so-called REM sleep, rapid eye movement
# 410.52 sleep, that's more pronounced in the later half of the night
# 413.02 and in doing so really get your sleep optimized,
# 415.26 not just in terms of duration but in terms of quality
# 417.81 and the overall architecture of your sleep.
# 419.85 This has a profound influence on your alertness, focus, mood,
# 423.143 and many other important factors throughout the day.
# 425.31 If you'd like to try Eight Sleep,
# 426.685 you can go to eightsleep.com/huberman to save
# 429.48 up to $150 off their Pod 3 cover.
# 431.79 Today's episode is also brought to us by Momentous Supplements.
# 434.55 I want to acknowledge that not everybody needs supplements,
# 437.008 and yet many, many people derive tremendous benefit
# 439.47 from proper supplementation.
# 441.37 I would count myself in that group.
# 442.92 There are excellent supplements for improving the depth
# 445.59 and quality of sleep,
# for improving focus,
# 448.38 and for improving energy and for hormone optimization
# 451.5 and many other factors related to our mental health, physical
# 454.23 health, and performance.
# 455.3 We've partnered with Momentous Supplements
# 457.05 for three important reasons.
# 458.262 First of all,
# Momentous supplements
# 459.72 are of the very highest quality.
# 461.342 Second of all, they ship internationally,
# 463.05 and we know that many of you reside
# 464.508 outside of the United States.
# 465.81 And third, they focus on single ingredient formulations.
# 468.67 This is very important.
# 469.75 There is a place for blends.
# 471.21 But in most cases, if you're going to develop a supplement
# 474.09 protocol, you want it to be single-ingredient formulations
# 477.03 so that you can adjust the dosages of different things
# 479.28 according to what works and doesn't work for you, which
# 481.572 is essentially impossible to do if you are using
# 483.63 multi-ingredient formulations.
# 485.29 If you'd like to see the supplements that I take
# 487.29 and that we've discussed here on the Huberman Lab podcast,
# 489.707 you can go to livemomentous--
# spelled O-U-S--
# 491.82 so livemomentous.com/huberman and get 20% off any
# 496.18 supplements.
# 496.68 Again, that's livemomentous.com/huberman
# 499.17 to get 20% off.
# 500.52 Let's talk about fertility.
# 501.78 And in doing so, let's take a step back from this word
# 504.12 "fertility" and ask, what is fertility and fertilization
# 507.45 really all about?
# 508.69 Well, the obvious answer is that it's about producing offspring.
# 511.77 But more importantly, it's about producing offspring
# 514.95 that contain the genetic components of both parents
# 518.61 and indeed contain half of the genes from one parent
# 521.82 and half of the genes from another parent.
# 523.74 Now, there are two general types of cells in the body.
# 526.73 The most common types of cells in the body
# 528.48 are called somatic cells.
# 529.57 So these would be all the cells in your body
# 531.403 except the egg in females and the sperm in males.
# 534.9 The egg in females and the sperm males
# 537.33 are part of what's called the germline.
# 539.04 And again, it has nothing to do with infection.
# 540.998 It's just that the cells of the germline have genes that cannot
# 545.34 be modified by the behavior of the individual that houses
# 549.3 those genes.
# 550.2 What do I mean by that?
# 551.26 Well, if I were to tell you that by exercising you can improve
# 554.31 mitochondrial function,
# you can change hormones
# 558.54 by reducing stress,
# you can reduce cortisol
# 560.91 by hitting puberty,
# for instance, you
# 564.36 will have the secretion of hormones that then change
# 566.845 gene expression in other cells, leading
# 568.47 to the development of body hair, facial hair,
# 571.14 deepening the voice,
# breast growth, et cetera,
# 573.925 you'd say, OK, great.
# 574.8 Yeah, that all makes perfect sense.
# 576.91 But that's all occurring in the so-called somatic cells.
# 579.6 The germ cells or the germline cells--
# 581.91 that is, the egg and the sperm--
# 583.98 are a very unique and protected set
# 586.26 of cells that are generated in a particular way
# 589.47 and whose genetic components are not modifiable by experience.
# 595.272 And when you take a step back and you think about it,
# 597.48 you say, oh, that's right.
# 598.563 There's no reason to think that exercising
# 600.99 will make the children that you have not yet had stronger.
# 605.02 And you say, of course not.
# 606.27 Well, why is that?
# 607.09 Well, that's because there is a barrier
# 609.27 between the genes of the germline cells and behaviors.
# 614.01 They cannot be modified by behaviors and the various
# 616.62 things that you do in your lifetime.
# 618.39 Now, I suppose there's an exception
# 619.92 in the negative direction.
# 621.96 And what I'm referring to here is if you were to, say,
# 624.3 be exposed to a chemical that could mutate the DNA
# 627.15 of your egg or sperm or if you were to fertilize an embryo
# 632.01 in a certain way or at a certain stage of life that it got
# 635.07 an extra chromosome,
# for instance--
# 636.528 we'll talk about this a little bit later--
# 638.278 well, then, of course,
# you could end up
# 639.96 with offspring that have modified
# 642.24 DNA that don't faithfully represent half of the genes
# 645.75 from mom and half of the genes from dad.
# 648.21 But that's not the same as specific behaviors
# 651.39 modifying the genes of those cells--
# 653.55 the sperm and the egg cells--
# 655.32 in a way that improves the offspring.
# 658.71 So the key first thing to understand today
# 660.613 is that there's a distinction between somatic cells, which
# 663.03 is the vast majority of cells in your body,
# 664.44 and the so-called germline cells, which
# 665.79 are the egg and the sperm.
# 666.873 The egg and the sperm are these highly protected populations
# 669.69 of cells that, in females, actually come
# 673.41 to be during embryogenesis.
# 676.11 So for all females out there, you
# 678.84 generate what today I'm going to refer to as a vault of cells.
# 682.44 You have a vault of eggs that are your germline.
# 686.73 Those eggs all contain all the chromosomes of your DNA.
# 692.08 So it's going to be-- as most of you
# 693.62 know, there are 23 chromosomes,
# and chromosomes exist in pairs.
# 697.45 So the way to think about this is each pair is one strand,
# 700.53 and you have 22
# so-called autosomes,
# 702.66 and then you have one sex chromosome.
# 704.4 The sex chromosome will be either X or Y. So in a female,
# 707.38 they have two X chromosomes.
# 708.76 So in each one of the eggs that a woman has
# 711.12 and that she's had since she was an embryo
# 713.64 and that's contained in this vault,
# 715.5 those eggs are, of course, going to be very immature at birth.
# 719.52 She hasn't undergone puberty yet.
# 720.96 And certainly, as an embryo,
# she hasn't undergone puberty.
# 723.51 And those cells are going to contain
# 725.91 23 pairs of chromosomes.
# 728.81 This is very important--
# 729.81 23 pairs of chromosomes.
# 732.1 The chromosomes are essentially the wrapped-up DNA
# 736.32 that contains all the genetic information
# 738.33 to create any cell type in the body
# 740.19 and actually to create an entirely new individual.
# 743.41 Now, there are 23 pairs of chromosomes, 22 of which
# 746.76 are called autosomes.
# 748.433 If that doesn't make sense to you,
# 749.85 just remember, autosome,
# OK, there's 22 of them.
# 752.32 And then there's one so-called sex chromosome.
# 754.5 The sex chromosomes are either X or Y. But this is a female,
# 757.99 so she's going to have
# 23 pairs of chromosomes,
# 760.5 and she's going to have two X chromosomes for the sex
# 764.4 chromosomes.
# 765.118 If this is already confusing to you, don't worry,
# 767.16 I'll make it very clear how this all relates to fertility
# 770.13 and how it relates to chromosomal segregation
# 773.01 and a bunch of things that I think maybe you've heard of
# 775.59 and that perhaps were opaque to you.
# 777.945 But I promise to make them clear.
# 779.32 But just understand that,
# within each of those eggs,
# 781.487 they have 23 pairs of chromosomes.
# 783.57 And for those of you that like nomenclature,
# 786.78 I'll tell you that those cells are considered diploid.
# 789.42 They're called the diploid, and that
# 791.16 means that they have 23
# pairs of chromosomes,
# 794.01 as distinguished from cells that are
# 796.89 haploid where there's only one set of those 23 chromosomes.
# 802.21 So instead of 23 pairs,
# there's only 23 chromosomes.
# 805.0 We'll come back to haploid cells a little bit later.
# 808.51 So when a female is born,
# she has all these eggs
# 812.46 in the reserve, in this vault, that she'll
# 814.53 have for her entire life.
# 815.64 She's not going to make any more.
# 817.26 But they are very,
# very immature.
# 819.24 So when a woman is in embryogenesis,
# 821.79 she develops these very immature eggs.
# 824.932 Today we're also going to talk about follicles,
# 826.89 and we will be careful to distinguish follicles
# 830.16 from eggs.
# 830.85 They're often talked about interchangeably, online
# 833.43 and elsewhere and even by fertility docs and OB/GYNs.
# 836.16 But right now we're just talking about the egg cells, the eggs
# 840.33 themselves, which are cells.
# 842.64 Now, the goal of fertilization is
# 845.58 to bring that egg cell into close enough proximity
# 848.31 that it can be fertilized by a single sperm cell.
# 852.3 And that sperm cell will bring 23 chromosomes, as well,
# 856.89 that include--
# 857.73 just as in the female egg, it'll have 22 autosomes and one sex
# 862.38 chromosome.
# 863.17 And in the male,
# that sex chromosome
# 864.87 can either be an X chromosome,
# which then would give rise
# 868.91 to female offspring, or a Y chromosome, which would
# 872.0 give rise to male offspring.
# 873.92 And today we're not talking about sexual differentiation.
# 876.62 That's a topic of a previous and yet another future episode.
# 879.44 But just to give you a sense of how X chromosomes and Y
# 883.22 chromosomes can actually accomplish
# 885.11 that sexual differentiation,
# both of body and brain.
# 889.73 I'll just mention in two sentences that, for instance,
# 892.8 if there's a Y chromosome as opposed to an X chromosome,
# 895.58 that Y chromosome contains genes that suppress, for instance,
# 899.76 the development of female genitalia
# 901.88 and thereby give rise to male genitalia.
# 905.458 So rather than the formation of a clitoris,
# 907.25 it's the formation of a penis.
# 908.902 And rather than the formation of ovaries,
# 910.61 the formation of a testes.
# 912.14 So that's more directed towards sexual differentiation.
# 914.438 We're not going to get into that right now.
# 916.23 We'll get into that in a future episode.
# 918.05 But even if you're only tracking about 10%
# 921.56 of what I'm saying right now,
# I promise you're doing great.
# 924.15 If you're tracking more than 10%, well,
# 925.82 then you're doing terrifically well,
# 927.32 because the essence of fertility and fertilization is to bring
# 930.44 together that haploid cell that is the sperm that only has 23
# 937.34 chromosomes-- but not pairs of chromosomes
# 940.55 because that's the DNA from dad--
# 942.47 together with the egg,
# which, as I told you already,
# 945.95 has 23 pairs of chromosomes.
# 947.97 So part of the fertilization process
# 950.57 has to be to get rid of one half of those 23 pairs
# 954.56 in the female.
# 955.25 You got to get rid of it, and you
# 958.36 have to get the egg and the sperm in proximity
# 960.82 so that the egg can potentially be fertilized
# 963.4 by the sperm bringing the DNA, the 23
# 967.24 single strands of chromosomes from dad,
# 971.53 into a cell that has 23
# single strands from mom.
# 976.13 So I realize I'm probably being a little bit repetitive here,
# 978.79 but I want everyone to understand this
# 981.34 because it really frames up fertility and reproduction
# 984.55 in the proper way.
# 986.77 We've got a cell from mom, the egg, which
# 989.65 has 23 pairs of chromosomes.
# 992.87 We need to get rid of one set of those pairs
# 995.86 so that there's only 23 chromosomes.
# 997.75 We need to get rid of half of those chromosomes.
# 1000.3 And then we need to bring that cell together physically
# 1003.54 with the sperm cell that contains the 23
# 1008.13 chromosomal strands from dad.
# 1010.562 And we need to bring those together so that you
# 1012.52 get 23 chromosomal pairs from dad
# 1014.86 and 23 chromosomal pairs from mom.
# 1018.01 And in doing so, you create a cell, which
# 1022.21 then becomes multiple cells.
# 1023.62 That's going to be the developing embryo that
# 1025.569 has half the genes from mom and half the genes from dad.
# 1028.089 So I hope that's clear.
# 1029.56 That is the biological logic, which I realize
# 1032.342 is a bit of a tongue twister.
# 1033.55 But forgive me.
# 1034.96 It is the most accurate way to describe this process.
# 1037.72 We're trying to bring together the 23 single strands
# 1041.589 of chromosomes from dad and the 23
# 1043.48 single strands of chromosomes from mom into the same cell.
# 1047.95 Now, that requires a literal physical contact
# 1051.85 and pairing of the two cells.
# 1053.38 But as I mentioned before,
# all these eggs in mom
# 1057.76 are sitting in a vault, and they're very, very immature.
# 1060.58 So the ovulatory cycle and the menstrual cycle
# 1064.45 are really about first eliminating
# 1067.06 half of the chromosomal pairs in that 23 sets of chromosomes
# 1071.86 and not getting rid of,
# for instance, half--
# 1074.71 just going 1 to 11 or 12 to 23.
# 1079.42 That's not the goal.
# 1080.39 The goal is to have chromosomes 1, 2, 3, 4, 5,
# 1082.84 6, all the way up to
# 23, but only to have
# 1085.6 half of the chromosomes there and to bring that cell together
# 1089.23 with the sperm cell,
# physically, then allow
# 1091.99 them to fuse and allow the chromosomes from dad
# 1094.99 and the chromosomes from mom to fuse within a single cell
# 1098.38 and duplicate into cells that contain half of the chromosomes
# 1102.07 from dad and half of the chromosomes from mom.
# 1104.29 That's what the ovulatory and menstrual cycle
# 1106.42 are really all about.
# 1107.752 So when thinking about it that way,
# 1109.21 I'd like to just initiate the discussion by focusing first
# 1112.09 on the female component,
# or the egg component,
# 1115.78 of fertility and fertilization.
# 1119.65 As I mentioned before, a female has all the eggs,
# 1123.31 albeit very immature eggs, that she's going to have at the time
# 1126.82 that she's born.
# 1128.32 Now, puberty will happen at some point
# 1132.34 and will allow the ovulatory and the menstrual cycle
# 1135.7 to commence.
# 1137.095 Now, one question that you perhaps are asking
# 1138.97 is, what controls the onset of puberty?
# 1141.1 And there are a number of different results,
# 1144.053 each of which could be an entire episode
# 1145.72 of a podcast on its own.
# 1147.04 But I'll just highlight a few things
# 1148.54 that we know about the onset of menses or menstruation,
# 1152.77 or it's sometimes also called a menarche.
# 1154.942 One thing that you'll notice about today's discussion
# 1157.15 is that if you were to take any number of your notes
# 1159.46 online and put them into a search function
# 1162.28 that you would see a lot of different language used
# 1164.68 for the same thing.
# 1165.65 So for instance,
# some people will
# 1166.45 talk about the egg and the follicle as the same thing,
# 1168.73 even though they are not.
# 1169.96 I'll explain the difference soon.
# 1171.335 Some people will talk about menses or menstruation
# 1173.5 or menarche as the exact same thing.
# 1175.19 And in fact, they are not the exact same thing,
# 1177.22 but oftentimes these words are used interchangeably.
# 1180.34 I'll do my best today to not overload you with nomenclature
# 1183.22 but rather to use the most commonly used terms
# 1186.97 for the different aspects of fertility and fertilization.
# 1189.94 But when it comes to the onset of puberty,
# 1192.7 first of all, most of you have probably
# 1195.01 heard that the onset of puberty is
# 1198.64 happening much earlier in females now
# 1200.89 than it was some years ago.
# 1202.31 And in fact, that is the case.
# 1204.13 And I'll talk about some statistics related
# 1206.05 to this which are pretty striking
# 1208.06 but don't necessarily point to anything detrimental.
# 1211.74 It doesn't necessarily mean that something bad is happening.
# 1214.24 What do we know for sure?
# 1215.38 Well, we know that there are a number
# 1217.75 of signals that come both through the brain
# 1220.3 and through the body--
# 1222.37 and more likely both-- in order to control the onset of puberty
# 1225.34 in females.
# 1226.27 A couple of examples-- the first is a mechanistic one.
# 1229.3 We know, for instance,
# that the entire process
# 1233.35 of the ovulatory menstrual cycle is initiated from the brain.
# 1236.398 We're going to get into this in a lot
# 1237.94 more detail in a few minutes.
# 1239.148 But there's a certain number of hormones and neurotransmitters
# 1242.86 that are communicated from the brain,
# 1245.2 a structure called the hypothalamus,
# 1247.01 which roughly sits above the roof of your mouth,
# 1249.7 and that communicates with a gland, an endocrine
# 1253.24 or hormone-releasing gland called the pituitary gland.
# 1256.85 The pituitary gland looks like a stalk that essentially
# 1261.58 extends out of the brain.
# 1263.06 It's also located not far from the roof of your mouth.
# 1266.14 And that has two sort of small marble
# 1268.9 or grape-sized protrusions,
# the anterior pituitary
# 1273.863 and the posterior pituitary.
# 1275.03 And they release different hormones into the bloodstream.
# 1278.29 Puberty is in part controlled by the fact
# 1281.59 that, up until puberty, there are
# 1284.56 neurons in the hypothalamus that release
# 1286.54 a neurotransmitter called GABA, which is inhibitory,
# 1288.97 and that prevents the neurons in the hypothalamus
# 1292.15 from releasing a very important hormone called
# 1296.35 gonadotropin-releasing hormone, or GnRH.
# 1299.42 So the first thing I'd really like everyone
# 1301.24 to know and commit to memory today is very easy--
# 1303.49 GnRH stands for gonadotropin-releasing hormone.
# 1306.95 This comes from the brain and will
# 1308.89 communicate to the pituitary to release certain hormones.
# 1312.37 Prior to puberty, in both males and females,
# 1316.33 there are neurons in the brain that are actively suppressing
# 1319.54 the neurons that release GnRH.
# 1321.49 It's like no puberty,
# no puberty, no puberty.
# 1323.925 You can't have puberty.
# 1324.942 You can't have puberty.
# 1325.9 And in fact, those cells are releasing this neurotransmitter
# 1329.85 called GABA because it's inhibitory.
# 1331.35 It prevents the firing of those neurons.
# 1333.8 So puberty is actively suppressed up
# 1335.95 until a certain point.
# 1337.06 It's also actively suppressed,
# at least in some species and we
# 1340.21 think at least partially in humans, by the tonic release--
# 1344.35 that means the ongoing release, around the clock--
# 1347.05 of a hormone called melatonin.
# 1349.48 Later in life-- in fact, after puberty--
# 1352.54 melatonin will be secreted only in the dark phase of each night
# 1357.1 and around the time that one goes to sleep.
# 1359.27 But in children and in particular
# 1361.96 in children prior to puberty, melatonin
# 1364.0 is released more or less constantly.
# 1366.67 Now, melatonin isn't the only source
# 1368.737 of suppression of puberty.
# 1369.82 It's also these neural mechanisms involving GABA.
# 1373.15 But it is certainly a great candidate for one
# 1376.39 of the reasons why puberty doesn't generally
# 1378.4 tend to happen at,
# say, age four age five.
# 1380.53 That would be very unusual.
# 1383.74 Another component of suppression of puberty
# 1387.49 is that typically in children they have relatively low body
# 1391.09 fat stores.
# 1391.85 Why is this important?
# 1392.81 Well, we know that one of the things that can trigger
# 1395.86 the onset of puberty-- in particular in females--
# 1398.77 is that when enough body fat accumulates,
# 1402.25 that body fat releases a hormone called leptin,
# 1405.64 and that hormone leptin travels in the bloodstream,
# 1408.55 across the blood-brain barrier,
# and goes to the hypothalamus
# 1411.31 and can trigger the onset of puberty
# 1412.99 by activating the neurons that release
# 1415.99 gonadotropin-releasing hormone.
# 1417.71 So many people believe that one of the reasons that puberty
# 1421.21 is happening earlier and earlier in females
# 1423.82 is because of the accumulation of more body fat at younger
# 1428.05 ages than was observed 30 or
# 40 and certainly 100 years ago.
# 1432.79 Now, I can already imagine a number of people are thinking,
# 1435.7 oh, this must relate to the obesity crisis.
# 1438.05 And indeed, there is a crisis of obesity.
# 1439.81 Obesity is something that is causing all sorts of problems
# 1444.94 with people's health at various levels, brain and body,
# 1447.94 and that is far more frequent today
# 1449.74 than it was even 20 years ago.
# 1451.76 So it is indeed a crisis because it
# 1453.55 has enormous detrimental effects for so many aspects
# 1456.79 of brain and body health and longevity.
# 1460.27 But this whole process of thinking about body fat
# 1462.807 signaling leptin to the hypothalamus and the onset
# 1464.89 of puberty doesn't necessarily have
# 1467.24 to do with the obesity crisis.
# 1468.49 It might relate, but it could also relate to, for instance,
# 1471.52 improved nutrition,
# which is allowing body
# 1473.83 fat stores to accumulate maybe not to the level of obesity
# 1476.89 but to accumulate earlier and at younger ages
# 1480.1 in females, which is then causing
# 1482.23 earlier puberty in females.
# 1484.39 To just highlight how that might be possible,
# 1486.67 I want to review some data that talk about the onset of menses,
# 1490.63 menstruation--
# that is, puberty--
# 1492.67 in females according to country and according
# 1495.7 to age over the last
# 100 or more years.
# 1499.01 So what are the general trends in terms
# 1500.752 of the onset of puberty in females?
# 1502.21 Well, that's an easy one to answer.
# 1504.94 Over the last 100 years or so, the onset of puberty
# 1509.32 has been occurring much earlier with each passing decade.
# 1513.88 It's really an incredible set of statistics.
# 1517.21 I will provide a link to these data
# 1518.71 since I know a number of you are listening and not
# 1520.793 just watching on YouTube.
# 1522.62 This is from a study in which the onset of puberty
# 1525.46 has been analyzed from as early as the 1850s--
# 1529.27 in certain countries,
# there are data on that--
# 1531.52 out to the 1970s and in other countries
# 1533.47 starting at about 1900,
# extending out to about 1990.
# 1537.55 These are ongoing collections of data.
# 1539.98 But just to give you a sense of how the data are falling out
# 1542.932 in a couple of different countries,
# 1544.39 just to give you a flavor--
# 1546.1 but for those of you listening and for those of you watching,
# 1550.21 the essence of all of these findings
# 1552.43 is that puberty is happening much, much earlier
# 1554.89 with each passing decade.
# 1556.15 So for instance, in the United States, around 1900 or 1903,
# 1562.28 the average age of menarche,
# the onset of puberty, in females
# 1566.14 was about 14 years old, whereas in 1990, the average age is 11.
# 1571.84 So that's a pretty significant, we can say,
# 1575.08 acceleration of the onset of puberty.
# 1577.61 Now, of course,
# these are averages.
# 1579.08 So there will be exceptions.
# 1580.55 There's a distribution of data.
# 1582.55 Today, still, there will be young females who
# 1585.22 will undergo puberty at age
# 11 or 10 or maybe even 9
# 1588.28 and others who will undergo puberty at age 13, 14, maybe
# 1591.67 even 16 or 17.
# 1593.44 However, if we look at, for instance,
# 1596.06 the data from Norway, which dates back quite far-- they
# 1598.57 have excellent record-keeping--
# to 1850, what we see
# 1602.14 is that the average age of the onset of female puberty in 1850
# 1606.73 in Norway was 17 years old, whereas in 1970, it's
# 1612.33 13 years old.
# 1613.69 So this is a dramatic acceleration
# 1616.11 of the onset of puberty.
# 1617.357 And you see a similar trend in other countries, as well.
# 1619.69 So if we were to look,
# for instance, in the UK,
# 1623.07 they have a smaller data set, meaning it only
# 1625.68 extends back to about 1940.
# 1627.81 But the average age of the onset of puberty in the UK in 1940
# 1631.98 was 13 and 1/2 years old.
# 1633.69 Again, this is just for females.
# 1635.52 And in 1970, it was closer to 13,
# 1638.46 with a trend towards declining even further.
# 1640.542 Unfortunately, they didn't continue
# 1642.0 to collect data out to 2022.
# 1644.76 And as a final point, if we were to look at, for instance,
# 1647.71 in Germany and Finland,
# the average onset
# 1651.06 of puberty in 1870 was
# 16 and 1/2 years old.
# 1654.9 By 1940, it was down to
# 13 and 1/2 years old.
# 1658.24 So all of these data have borne out over and over again,
# 1662.31 regardless of location in the world, which is important,
# 1664.68 because when you start to think about the obesity crisis,
# 1666.54 you can say, well, that's mainly in developed countries,
# 1668.91 believe it or not-- or perhaps not surprisingly.
# 1671.13 And maybe it has to do with the obesity crisis.
# 1673.57 And yet I don't think we can conclude that at all.
# 1676.2 Something is happening, however.
# 1678.33 It could be increased body fat stores
# 1681.18 due to overeating and obesity.
# 1682.75 However, it could also be-- unrelated to obesity,
# 1685.41 it could be, for instance, improved
# 1687.81 nutrition and the availability of quality nutrition, which
# 1691.53 can signal the maturation of the brain
# 1693.96 and body mechanisms that trigger the onset of puberty,
# 1696.96 ovulatory cycle,
# and menstruation.
# 1698.82 So we want to be very careful about leaping to conclusions
# 1701.37 about what these trends mean,
# but the trends themselves
# 1704.04 are very, very apparent.
# 1705.63 And as a final point, I should also
# 1707.43 mention that there are a number of different behavioral
# 1709.98 and psychosocial, as they're called, interactions that
# 1712.92 can influence puberty as well.
# 1714.64 This has been most strikingly observed in animals.
# 1717.61 And so I don't want anyone to be alarmed
# 1719.37 or to leap to any great conclusions about the onset
# 1722.31 of timing of puberty in humans, but I'd be remiss
# 1724.798 if I didn't tell you about a certain result which
# 1726.84 shows that if a young female is exposed to the odor--
# 1732.63 not necessarily the pheromones.
# 1734.16 There's a distinction between odors that we perceive
# 1736.77 and pheromones, which are subconscious.
# 1739.82 We don't actively perceive, but that can impact our biology,
# 1743.207 and pheromones effects in humans are very controversial.
# 1745.54 But we know, for instance, that if you take a female animal--
# 1748.56 and there's some evidence from humans
# 1750.63 that if you take a young prepubertal female
# 1753.6 and you expose her to the scent of a reproductively-competent
# 1759.45 male for a series of days,
# but maybe even as short
# 1765.3 as a few hours,
# and she is also not
# 1769.02 regularly being exposed to the scent of her father,
# 1772.59 that she can undergo puberty earlier.
# 1774.9 That's right.
# 1775.74 There is something about the odor
# 1777.72 and/or pheromones, or perhaps something else, that
# 1782.46 occurs when a young prepubertal female has a father that she's
# 1787.73 in regular contact with.
# 1788.73 He wouldn't necessarily have to live at home but that
# 1790.938 is around a lot that his smell is registered
# 1794.46 by her biological systems.
# 1796.71 That-- I don't want to say protects
# 1798.99 because it kind of skews the valence of the conversation,
# 1802.14 but that offsets or buffers the otherwise observed effect,
# 1808.39 which is that the scent of a reproductively-competent male,
# 1811.86 if it's present often enough or perhaps intensely enough,
# 1814.92 that it can trigger the onset of puberty in that female.
# 1817.44 In other words, the scent of a male that is not the father
# 1822.09 and we think also that is not biologically related to her
# 1825.12 can trigger earlier onset of puberty.
# 1827.85 And that effect can at least be partially buffered
# 1832.35 by her being in the presence of the scent
# 1836.04 from her biological father.
# 1837.99 Now, some of you are probably already leaping
# 1840.0 to conclusions about what this means.
# 1841.542 Should you not allow your daughter
# 1843.593 to be exposed to any males who are
# 1845.01 of reproductive age, et cetera?
# 1847.05 That's certainly not what I'm saying.
# 1848.635 There's a huge number of considerations
# 1850.26 that go into that calculation for everybody
# 1852.78 and circumstances, et cetera.
# 1854.52 But the point is that the odors of individuals, both related--
# 1860.97 in particular, closely related--
# and non-related individuals,
# 1865.41 can shape the neural systems and the hormone systems that
# 1870.597 can trigger the onset of puberty or suppress
# 1872.43 the onset of puberty.
# 1873.54 So whether or not we're talking about onset
# 1875.37 of puberty at this age or that age
# 1877.05 and whether or not biologically-related male
# 1880.14 or non-biologically-related male scents around,
# 1882.24 et cetera, the thing I want everyone to know
# 1885.09 is that at some point during development,
# 1887.85 typically nowadays between the ages of 11 and 15
# 1892.77 or so-- again, there's variability there.
# 1896.55 The suppression of gonadotropin-releasing hormone
# 1899.49 released from the hypothalamus is removed,
# 1901.77 and then gonadotropin-releasing hormone
# 1904.47 can activate cells within the pituitary.
# 1907.11 And if you really want to know, it's
# 1908.61 the anterior pituitary in particular.
# 1910.77 And then the anterior pituitary gland,
# 1913.3 which sits at and kind of bridges the brain and the body
# 1917.25 because it allows the release of hormones into the bloodstream,
# 1921.27 that anterior pituitary is going to release
# 1923.52 two key hormones that everyone should know the name of
# 1926.52 and what they do.
# 1927.46 And when I say everyone,
# I mean males and females
# 1929.55 need to know about these hormones
# 1931.2 because they have an active role in both males and females.
# 1934.09 And of course, you should want to know
# 1936.33 and should know about the biology of everyone
# 1939.15 on the planet, in my opinion, because it tells you
# 1941.773 a lot more about humans than if you just
# 1943.44 focus on your own biology.
# 1944.82 But those two hormones are called
# 1946.83 luteinizing hormone,
# which is abbreviated LH,
# 1951.12 and follicle-stimulating hormone, which
# 1954.03 is abbreviated FSH.
# 1955.89 So the simple picture that you need to have in your mind
# 1958.83 is gonadotropin-releasing hormone from the brain,
# 1961.23 from the hypothalamus in particular,
# 1963.45 is causing the release of luteinizing
# 1966.09 hormone and follicle-stimulating hormone, GnRH stimulates
# 1970.92 LH, luteinizing hormone, and follicle-stimulating hormone,
# 1973.89 FSH.
# 1975.09 LH and FSH travel in the blood and can access all the cells
# 1979.38 and tissues of the body.
# 1980.38 This is one of the incredible things about hormones is that
# 1984.33 many hormones-- and LH and FSH are included in this group--
# 1988.83 can travel into cells,
# and they can actually
# 1992.55 change the genetic expression of those cells.
# 1995.04 They can change which genes are turned on
# 1996.9 and which genes are turned off.
# 1998.192 And they can also attach to the surface of those cells
# 2001.367 and make those cells take on different properties.
# 2003.45 So they can mature those cells.
# 2004.742 So for instance, a good example of this outside
# 2007.31 of the context we've been talking about
# 2008.99 is the hormone testosterone can travel to the hair follicle
# 2012.365 and can stimulate changes in the genes of the cells of the hair
# 2014.99 follicle that can make hair grow.
# 2017.12 A different hormone,
# estrogen, can
# 2019.19 travel to the cells of the breast tissue
# 2021.8 and activate genes that control enlargement of the cells
# 2024.29 of the breast tissue.
# 2025.28 Prolactin, a different hormone,
# can travel to the mammary ducts
# 2028.52 and control the production and the secretion of milk.
# 2032.09 And in males, that can actually happen, in certain cases,
# 2035.55 although it's rare.
# 2036.53 But prolactin can also travel to areas of the brain
# 2039.11 that control libido,
# for instance.
# 2041.09 And just so you'll never forget it,
# 2043.34 males' elevated levels of prolactin
# 2045.44 are actually what set the refractory period
# 2047.54 after ejaculation and prevent erection
# 2049.639 for some period of time.
# 2050.94 So you'll never forget prolactin.
# 2053.96 The point being that different hormones
# 2056.09 have different effects on different cells,
# 2057.889 depending on what cells those are.
# 2059.366 Estrogen or estradiol is going to have different effects
# 2061.699 on the breast tissue than it would on skin,
# 2064.37 although as effects on both.
# 2065.84 Similarly, when LH and FSH, luteinizing hormone
# 2069.71 and follicle-stimulating hormone, travel in the blood
# 2072.83 to the gonad and the gonad is an ovary,
# 2076.82 it will have a certain set of consequences.
# 2079.86 And when luteinizing hormone and follicle-stimulating hormone
# 2082.48 travel in the blood to a gonad and that gonad
# 2084.909 happens to be a teste, then it will have a different set
# 2087.82 of biological implications.
# 2089.69 So let's focus now on what happens when
# 2092.08 LH and FSH arrive at the ovary.
# 2094.989 And let's assume now that we're talking about a female who
# 2099.19 has already undergone puberty, or perhaps we
# 2102.88 could even frame this in the context of a female who
# 2105.46 is about to undergo puberty.
# 2107.77 FSH and LH are now able to be released because she's
# 2110.65 undergoing puberty.
# 2112.12 But the same set of processes, essentially,
# 2114.82 would occur for any point from puberty onward until menopause,
# 2119.51 which is the depletion of that vault, that ovarian reserve
# 2124.18 of all those immature eggs.
# 2125.68 I'd like to take a brief break and acknowledge
# 2127.75 our sponsor, Athletic Greens.
# 2129.79 Athletic Greens is an all-in-one vitamin mineral probiotic
# 2132.97 drink that also contains digestive enzymes
# 2135.34 and adaptogens.
# 2136.42 I started taking Athletic Greens way back in 2012,
# 2139.6 so that's 10 years now of taking Athletic
# 2141.55 Greens every single day.
# 2142.91 So I'm delighted that they're sponsoring this podcast.
# 2145.223 The reason I started taking Athletic Greens and the reason
# 2147.64 I still take Athletic Greens is that it
# 2149.62 covers all of my foundational nutritional needs.
# 2152.205 So whether or not I'm eating well
# 2153.58 or enough or not, I'm sure that I'm covering all of my needs
# 2156.61 for vitamins,
# minerals, probiotics,
# 2158.53 adaptogens to combat stress,
# and the digestive enzymes really
# 2162.1 help my digestion.
# 2163.12 I just feel much better when I'm drinking Athletic Greens.
# 2165.598 If you'd like to try Athletic Greens,
# 2167.14 you can go to athleticgreens.com/huberman,
# 2169.96 and for the month of January,
# they have a special offer where
# 2172.69 they'll give you 10 free travel packs plus a year supply
# 2176.11 of vitamin D3/K2.
# 2177.58 Vitamin D3 and K2 are vital for immune function,
# 2180.73 metabolic function,
# hormone health,
# 2182.38 but also calcium regulation and heart health.
# 2184.9 Again, that's athleticgreens.com/huberman
# 2187.84 to claim their special offer in the month of January of 10 free
# 2190.87 travel packs plus a year supply of vitamin D3/K2.
# 2194.38 OK, so we're now going to talk about ovulation
# 2196.36 and menstruation, and let's just remember
# 2198.068 what this is all about.
# 2199.1 This is all about creating the potential for an egg
# 2202.39 to be fertilized,
# and that egg needs
# 2204.22 to have half of the chromosomal pairs, so no pairs,
# 2208.18 but it's got to have 23
# chromosomes just from mom.
# 2211.12 And we need to position that egg so
# 2213.82 that the egg can be met by the sperm
# 2216.82 and that sperm can penetrate that egg
# 2219.01 and donate its 23 individual strands of chromosomes
# 2224.2 to that egg so that you can bring together the DNA of dad
# 2227.95 and the DNA of mom.
# 2229.3 So the obligatory menstrual cycle
# 2231.46 occurs when luteinizing hormone and follicle-stimulating
# 2236.08 hormone have been released.
# 2238.12 And the ovulatory/menstrual cycle--
# 2241.81 and here I have to kind of pick what I want to call it.
# 2244.683 I guess to be really accurate,
# we would just call it
# 2246.85 the female reproductive cycle,
# but that includes underneath it
# 2250.545 both the menstrual cycle,
# as it's sometimes called,
# 2252.67 and the ovulatory cycle.
# 2254.0 So you decide.
# 2254.95 I'm going to interchangeably discuss the ovulatory cycle
# 2258.25 and the menstrual cycle.
# 2259.47 The problem is, when you say menstruation,
# 2261.22 people often think about just the period, the shedding
# 2263.59 of the uterine lining when fertilization has not occurred.
# 2266.63 So if I start saying ovulatory cycle,
# 2269.35 just keep in mind I'm referring to the entire thing.
# 2272.57 Now, this is probably also a good opportunity
# 2274.78 to say that if you heard that the ovulatory/menstrual cycle
# 2279.37 is 28 days long, that's true in some cases,
# 2282.85 but that's not always true.
# 2284.42 It's, on average, 28 days long.
# 2287.2 There are some females for which the ovulatory cycle will be
# 2291.49 shorter-- it can be as short as 21 days--
# 2293.68 and other females for which it will be 35 days long.
# 2298.48 Shorter than 21 days and longer than 35
# 2300.85 days is rare, although it does occur.
# 2303.465 One of the key things when thinking about fertility
# 2305.59 is if you talk to OB/GYNs who are focused on fertility, which
# 2308.8 I have in anticipation of this episode,
# 2310.72 they'll tell you that whether or not
# 2313.03 your cycle is 21 days long or 35 days long
# 2316.9 is not as much of an issue necessarily unless it's
# 2320.53 happening to become much shorter or much longer
# 2324.1 in a kind of erratic way.
# 2325.88 So if you're somebody who's consistently
# 2327.64 had 23 day long cycles and all of a sudden
# 2330.19 you're having 30 day long cycles, that's not necessarily
# 2333.01 an indication of anything bad.
# 2334.39 But if it's 21 days one month and it's 30 days the next month
# 2338.33 and it's 17 days the next month or even if it's always
# 2341.95 falling within that 21
# to 35 day long cycle
# 2345.1 but it's very variable from each month or every other month
# 2348.04 or so, you probably want to talk to your OB/GYN
# 2351.605 because that could indicate a number of different things.
# 2353.98 Which things could it indicate?
# 2355.3 Well, that will become clear as I spell out
# 2357.25 the biology in a bit more detail.
# 2359.35 But this idea that the menstrual cycle/ovulatory cycle
# 2362.35 is always 28 days,
# that's just false.
# 2364.33 That's just not true.
# 2365.89 I should also mention that there is a common misconception that
# 2369.58 because the average menstrual cycle is 28 days-- indeed,
# 2372.67 the average is 28 days--
# 2374.14 and the lunar cycle is 28 days--
# 2376.607 and of course, there is a real biology
# 2378.19 to support the fact that the lunar
# 2379.607 cycle can't, in fact,
# impact certain aspects
# 2382.14 of human behavior.
# 2383.62 It does, and we'll talk about lunar cycles
# 2385.56 in a future episode.
# 2386.82 But there is zero data to support the idea
# 2390.18 that the menstrual cycle and the lunar cycle
# 2393.03 are linked in any kind of causal way.
# 2396.12 Sorry to break it to you.
# 2397.5 The lunar cycle and the tidal cycles at the ocean
# 2401.407 are definitely linked in ways that are super interesting
# 2403.74 related to the tilt of the Earth and the pull of gravity
# 2405.72 of different planets, and it's an incredible story
# 2407.94 into itself.
# 2409.02 But the lunar cycle and the menstrual cycle,
# 2411.3 despite having some weak correlation in terms
# 2413.85 of their duration or their so-called periodicity--
# 2418.41 no pun intended--
# 2420.21 well, there's no causal relationship whatsoever
# 2422.88 between the lunar cycle and the menstrual cycle.
# 2425.5 If any of you are aware of any real data
# 2428.88 that conflicts with what I just said,
# ...
# 14991.31 although I, of course,
# should point out
# 14993.26 that females should get the recommended daily allowance
# 14996.74 of zinc each day.
# 14998.0 Males, on the other hand, seem to benefit
# 15000.58 from having additionally high levels of zinc intake.
# 15004.163 Now, that can be obtained through foods.
# 15005.83 You often hear, oh, oysters are enriched in zinc,
# 15008.62 and oysters are an aphrodisiac.
# 15011.205 I don't know who's doing the marketing for oysters,
# 15013.33 but it's really terrific.
# 15015.08 I think that seems to have persisted.
# 15016.69 And maybe it's true.
# 15019.51 Oysters are enriched in zinc.
# 15021.04 What does zinc do for fertility?
# 15023.87 Well, in males, we know,
# based on a really nice set
# 15026.74 of studies, that zinc dosages that
# 15029.23 are pretty high of about 120 milligrams
# 15031.72 taken twice per day--
# 15033.73 that's quite a lot-- with meals can significantly
# 15037.24 increase testosterone and dihydrotestosterone.
# 15040.54 And this probably shouldn't come as a surprise to us.
# 15042.86 It turns out that zinc is highly enriched in human testes
# 15046.54 and in the testes of other animals,
# 15048.2 including fish and other mammals.
# 15049.72 And it was actually in 1921
# that it was observed in fish
# 15054.76 that zinc levels skyrocket in the testes of fish
# 15058.54 during their breeding season.
# 15060.02 So zinc is correlated with increases in breeding,
# 15062.973 but you never know which direction
# 15064.39 that correlation is running.
# 15065.77 It turns out that zinc in both animals,
# 15069.56 including fish, other mammals,
# and in humans, strongly
# 15073.06 impacts the enzymatic functions in the testes,
# 15075.55 including the function of androgen-binding protein.
# 15078.8 So it seems that high levels of zinc
# 15080.38 can increase spermatogenesis and testosterone
# 15082.75 levels very significantly.
# 15085.193 This was explored in a really nice study
# 15086.86 that I'll provide a reference to.
# 15087.88 It's an older study.
# 15088.73 But I really like.
# 15089.56 It's called "Effect of Zinc Administration
# 15091.31 on Plasma Testosterone,
# Dihydrotestosterone,
# 15093.55 and Sperm Count."
# 15094.75 This is but just one study among many now.
# 15098.29 This dates back to 1981,
# but there have been studies
# 15101.41 subsequently that point to the fact that supplementation
# 15103.81 with zinc at those high levels can really
# 15105.518 be helpful in terms of increasing
# 15108.4 sperm count,
# testosterone, and even
# 15111.04 testicular size, of all things.
# 15113.03 So one important point about taking
# 15115.75 zinc-- this 120 milligrams of zinc two times daily
# 15119.225 definitely needs to be done with meals.
# 15120.85 If you've ever taken zinc on an empty stomach,
# 15122.92 even if you just take 15
# or 30 milligrams of zinc,
# 15125.59 you can feel very nauseous,
# not well, for a few hours.
# 15129.1 So make sure that you're taking zinc with full meals.
# 15131.83 So this would mean that you're taking in at least
# 15134.59 two full meals per day.
# 15137.83 I should also mention that zinc supplementation did not
# 15140.26 appear to impact gonadotropin-releasing hormone
# 15143.2 or prolactin.
# 15143.89 So it seems to be a fairly targeted effect
# 15146.29 on the testosterone and related pathways in males.
# 15148.84 As far as I know, there have not been systematic explorations
# 15152.08 of the effects of high levels of zinc administration on females.
# 15155.325 I would hope that those studies would soon be done.
# 15157.45 But meanwhile, if you're a male and you're
# 15159.28 interested in improving sperm quality
# 15160.93 and your testosterone levels overall for whatever reason,
# 15164.02 zinc likely is a good candidate.
# 15166.0 And that pretty much summarizes the compounds
# 15168.28 that men and women should take in order
# 15170.35 to maximize egg quality,
# sperm quality, and fertility.
# 15173.157 And then, of course,
# we start to enter
# 15174.74 the landscape of other things that men and women can take
# 15177.5 in order to improve fertility,
# and those other things
# 15180.26 generally are prescription drugs.
# 15182.39 And so I just want to mention what a few of those are.
# 15184.815 But of course, these are things that you would absolutely
# 15187.19 have to obtain prescriptions for from your MD,
# 15191.03 and your MD, without question, would
# 15194.3 want to take blood tests prior to prescribing these things.
# 15197.22 So for instance,
# if men have been
# 15199.4 taking exogenous testosterone through the use
# 15202.1 of anabolic steroids, like performance-enhancing drugs
# 15204.56 or even testosterone replacement therapy,
# 15206.54 their endogenous testosterone levels
# 15208.19 are going to be very low,
# and their sperm counts
# 15210.193 are going to be very low,
# unless, for instance, they
# 15212.36 are prescribed and taking something
# 15213.89 like hCG, human chorionic gonadotropin, which
# 15217.55 mimics LH and would stimulate the testes to produce
# 15220.16 testosterone and through some indirect pathways rescue
# 15223.4 spermatogenesis, although not to the same degree
# 15225.83 as if people are not taking exogenous sources
# 15229.1 of testosterone.
# 15230.33 Some men, even if they've never touched TRT or exogenous
# 15234.32 testosterone of any kind, will be prescribed
# 15237.29 to take hCG because of its ability
# 15239.42 to stimulate the testes to produce
# 15241.31 more testosterone and sperm.
# 15242.7 So they're just taking hCG alone.
# 15244.61 Other men will take--
# 15245.84 or will be prescribed, rather--
# 15247.43 FSH in order to stimulate spermatogenesis, or hCG
# 15250.64 and FSH, or clomiphene,
# which can regulate
# 15254.18 all sorts of things in the both testosterone and
# 15256.49 estrogen-related pathways at the level of brain and pituitary
# 15260.81 and gonad, testes.
# 15263.54 Likewise, for women,
# if they're low in FSH,
# 15265.85 they might be prescribed FSH.
# 15267.77 If they are low in luteinizing hormone,
# 15270.68 they might be prescribed hCG.
# 15272.15 If they're low in testosterone, they might even
# 15273.71 be prescribed testosterone.
# 15274.85 And if their testosterone is too high
# 15276.41 and they're dealing with PCOS, they
# 15277.88 might be prescribed anti-androgens and androgen
# 15280.82 blockers and on and on and on.
# 15283.32 There are so many different hormones that
# 15285.26 can impact the different aspects of the ovulatory
# 15287.6 and the spermatogenesis cycle that the OB/GYNs
# 15291.95 and the urologists focused on male fertility nowadays really
# 15295.04 have an excellent handle on which levers and buttons
# 15297.83 and threads to pull and push and so forth in order
# 15300.59 to set in motion a proper ovulatory
# 15303.14 cycle and a proper spermatogenesis cycle.
# 15306.08 Everything we talked about up until now
# 15308.305 and in the early phase of this episode,
# 15309.93 especially, about how the brain commands
# 15312.92 the pituitary and the pituitary commands the gonads and then
# 15315.89 the gonads, the ovary, or the testes
# 15317.72 send feedback signals to the pituitary
# 15320.0 to then influence the pituitary, all
# 15321.98 of that incredible orchestra, that dance,
# 15324.44 is so tightly regulated in a way that really provides
# 15327.92 the OB/GYNs and the fertility docs
# 15329.99 concerned with male fertility exceptional tools to,
# 15333.26 for instance, figure out if a man is not producing any sperm
# 15336.86 but his testosterone levels are well within normal range,
# 15340.28 well, then there are some very clear sets of explorations
# 15343.018 and potential treatments.
# 15344.06 Some of which are mechanical, making sure
# 15345.768 the epididymis and vas deferens are clear,
# 15347.69 allowing the sperm to enter the ejaculate
# 15349.79 and the ejaculate to enter the urethra
# 15351.47 and obviously to enter the female, as well
# 15355.93 as for a woman who's not ovulating
# 15357.88 to adjust her levels of FSH or maybe even to apply acupuncture
# 15362.65 in conjunction with supplementation
# 15364.39 and various prescription hormone therapies to adjust
# 15367.87 fertility and ovulation and the probability
# 15370.06 of successful pregnancy.
# 15371.93 So there's a vast landscape of prescription drugs
# 15374.56 and surgical interventions of varying degrees
# 15377.35 of invasiveness.
# 15379.33 And some are, for instance,
# outpatient procedures.
# 15383.14 Some require general anesthesia, et cetera,
# 15385.27 in order to maximize male and female fertility.
# 15388.39 What I've tried to do today is to provide you
# 15391.81 with a deep dive understanding of the ovulatory and menstrual
# 15396.39 cycle.
# 15396.89 We talked about the brain,
# the pituitary, the ovary,
# 15398.71 the Fallopian tubes, and, in fact,
# 15400.13 the whole female reproductive axis
# 15401.77 as it relates to fertility and reproduction
# 15406.15 I also describe the male reproductive axis as it relates
# 15410.62 to the brain, the pituitary,
# the gonad, the testes,
# 15413.2 and the various ducts, the pathways,
# 15415.18 out of the testes that allow the sperm to be enriched
# 15419.8 within the semen and then the semen and the ejaculate
# 15422.29 to exit through the urethra.
# 15424.15 I did all that as a way to frame the various tools
# 15426.85 and interventions that can really
# 15429.07 assist in increasing fertility,
# egg quality, and sperm quality.
# 15433.4 So when we discuss mitochondria in the context
# 15435.58 of the development of an egg or the development of sperm
# 15438.61 and its ability to swim quickly forward,
# 15441.7 now it should make sense as to why
# 15443.62 give an intervention,
# whether or not
# 15445.12 it's L-carnitine or whether or not
# 15446.537 it's exercise or whether or not it's getting enough sleep
# 15448.912 and limiting stress, why all that should matter and why,
# 15451.27 in fact, mechanistically those interventions can work.
# 15454.765 Because, indeed, there are many interventions
# 15456.64 that we can all do and use to support our fertility.
# 15460.33 And again, as a more general theme today,
# 15462.52 I really wanted to,
# A, teach you about
# 15464.71 the human reproductive axis--
# 15466.6 I do find the biology of the ovulatory and menstrual cycle
# 15470.23 and spermatogenesis to be absolutely fascinating to me.
# 15473.4 And again, if you're somebody who's interested in conceiving
# 15475.9 or if you've already conceived children
# 15477.73 and even if you don't want more children,
# 15479.65 this is really the aspect of our biology
# 15482.26 that allowed us to be here.
# 15484.45 It's the aspect of our biology that determined whether or not
# 15487.84 we are male or female.
# 15489.1 It's the aspect of our biology that determines so, so much,
# 15491.74 and yet I think that most of us generally are not
# 15494.47 taught this in school or at least not at the depth
# 15496.66 that we discussed it today.
# 15498.37 So hopefully that information was in and of itself
# 15501.07 interesting and perhaps useful as well.
# 15503.42 And I do think that even if people are not
# 15505.21 wishing to conceive more children that the information
# 15508.06 related to fertility and optimizing egg and sperm health
# 15510.91 is of value in the sense that optimizing egg and sperm health
# 15515.2 can be used as a proxy for optimizing our body and brain
# 15519.07 health generally.
# 15519.82 In other words-- and here I'm admittedly taking words out
# 15524.05 of the mouths of the various wonderful doctors,
# 15526.87 the OB/GYNs and neurologists that helped inform me
# 15530.35 in anticipation of this episode-- what is good
# 15532.9 for the woman is good for the egg
# 15535.03 and for fertility and for pregnancy.
# 15537.1 And what's good for the man is good for the quality
# 15541.42 and production of sperm and for fertility and pregnancy.
# 15545.56 Put differently, whether or not we are male or female,
# 15548.92 the things that we can do to optimize our fertility
# 15551.65 are the exact same things that we should all
# 15554.14 be doing to optimize our vitality and our longevity.
# 15557.57 And I realize today's episode was so much the deep dive
# 15560.59 and fairly broad, as well,
# that it ended up being
# 15563.56 fairly long and extensive.
# 15565.33 And yet we still have not touched
# 15567.378 on any of the important themes that I know a number of people
# 15569.92 want to know about-- so,
# for instance, menopause,
# 15573.43 andropause, PCOS,
# and other themes
# 15576.865 related to hormones and reproductive function
# 15578.74 and biology.
# 15579.47 And I promise that we will have episodes, both solo episodes
# 15582.79 and episodes with expert guests, in the future
# 15585.55 to cover all of those topics in detail.
# 15587.54 Meanwhile, the information discussed in today's episode
# 15590.23 should serve as a basic foundation
# 15592.51 for those discussions going forward
# 15594.07 and hopefully were of interest to you in their own right.
# 15596.5 If you're learning from and/or enjoying this podcast,
# 15598.76 please subscribe to our YouTube channel.
# 15600.44 That's a terrific,
# zero-cost way to support us.
# 15602.71 In addition, please subscribe to the podcast
# 15604.99 on Spotify and Apple.
# 15606.52 And on both Spotify and Apple, you
# 15608.08 can leave us up to a five star review.
# 15609.705 If you have questions or comments
# 15611.08 about the podcast or guests that you'd
# 15612.52 like me to bring on the Huberman Lab podcast,
# 15614.44 please put those questions and suggestions
# 15616.54 in the comment section on YouTube.
# 15618.13 I do read all the comments.
# 15620.05 In addition, please check out the sponsors
# 15622.06 mentioned at the beginning and throughout today's episode.
# 15624.7 That's the best way to support this podcast.
# 15627.16 During today's episode and on many previous episodes
# 15629.59 of the Huberman Lab podcast,
# we discussed supplements.
# 15632.11 While supplements aren't necessary for everybody,
# 15634.18 many people derive tremendous benefit from them
# 15636.28 for things like sleep,
# hormone augmentation, focus,
# 15638.95 and much more.
# 15640.032 The Huberman Lab podcast is now partnered
# 15641.74 with Momentous Supplements because, as I mentioned
# 15644.05 at the beginning of today's episode,
# 15645.58 Momentous Supplements are of the very highest quality,
# 15648.04 they ship internationally, and they
# 15649.84 have single-ingredient formulations
# 15651.82 that allow you to develop the most
# 15653.41 biologically-effective and cost-effective supplement
# 15655.89 regimen for you.
# 15656.913 If you'd like to see the supplements discussed
# 15658.83 on today's and other Huberman Lab podcasts,
# 15661.02 please go to livemomentous--
# spelled O-U-S--
# 15663.36 so livemomentous.com/huberman.
# 15666.42 If you're not already following us on social media,
# 15668.79 please do so.
# 15669.76 We are Huberman Lab on Instagram, Twitter, Facebook,
# 15672.34 and LinkedIn.
# 15673.08 And at all of those places, I discuss
# 15674.82 science and science-related tools, some of which
# 15677.1 overlap with the contents of the Huberman Lab podcast,
# 15679.35 but much of which is distinct from the content
# 15681.603 of the Huberman Lab podcast.
# 15682.77 So again, it's Huberman Lab on all social media platforms.
# 15685.807 And if you haven't already subscribed to our newsletter,
# 15688.14 we have a zero-cost newsletter.
# 15690.12 It is called the Neural Network Newsletter.
# 15692.04 And each month, it includes things like podcast summaries
# 15695.88 and toolkits for things like sleep,
# 15697.59 focus, dopamine optimization,
# fitness, and so on.
# 15701.25 You can sign up for the newsletter-- again,
# 15703.11 completely zero cost-- by going to hubermanlab.com.
# 15705.51 Go to the menu.
# 15706.21 Go to the newsletter.
# 15707.13 You provide your email, and we do not share your email.
# 15709.62 And again, the newsletter is completely zero cost.
# 15711.768 Thank you, once again, for joining me
# 15713.31 for today's discussion all about the biology surrounding
# 15716.508 this incredible thing that we call fertility, including
# 15718.8 the ovulatory cycle,
# spermatogenesis, fertilization
# 15722.1 itself, and all the events leading up to pregnancy.
# 15725.4 And last but certainly not least,
# 15727.495 thank you for your interest in science.
# 15729.12 [MUSIC PLAYING]

# %%
## Read the first dataset containing the YouTube chapters into a pandas DataFrame:
chapters = []
with open('Dataset/timestamps/Episode-5.txt', 'r') as f:
    for line in f:
        columns = line.strip().split(' ')
        time = columns[0]
        chapter = ' '.join(columns[1:])
        chapters.append([time, chapter])

chapters_df = pd.DataFrame(chapters, columns=['time', 'chapter'])

# %%
## Read the second dataset containing the YouTube transcripts into a pandas DataFrame:
transcripts = []
with open('Dataset/transcripts/Episode-5.txt', 'r') as f:
    for line in f:
        columns = line.strip().split(' ')
        second = columns[0]
        text = ' '.join(columns[1:])
        transcripts.append([second, text])

transcripts_df = pd.DataFrame(transcripts, columns=['second', 'text'])

# %%
## Aggregate the datasets
dataset = chapters_df

## Add the transcript column 
dataset['transcript'] = ''

for index, row in dataset.iterrows():
    # Set the start time of the chapter | Convert it to seconds
    start_time = row['time']
    start_time_object = datetime.datetime.strptime(start_time, "%H:%M:%S")
    start_time_seconds = start_time_object.hour * 3600 + start_time_object.minute * 60 + start_time_object.second

    # Get the next row
    if index < len(dataset)-1:
        end_time = dataset.iloc[index+1]['time']
    else:
        next_time = None
        next_text = None
        break
        
    # Set the end time of the chapter | Convert it to seconds
    end_time_object = datetime.datetime.strptime(end_time, "%H:%M:%S")
    end_time_seconds = end_time_object.hour * 3600 + end_time_object.minute * 60 + end_time_object.second

    # convert the 'time' column from string to float
    transcripts_df['second'] = transcripts_df['second'].astype(float)

    # select the rows with time between start_time and end_time, and concatenate the text values
    selected_text = transcripts_df.loc[(transcripts_df['second'] >= start_time_seconds) & (transcripts_df['second'] <= end_time_seconds), 'text'].str.cat(sep=' ')
    
    dataset.loc[index, 'transcript'] = str(selected_text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 26
#      23 end_time_seconds = end_time_object.hour * 3600 + end_time_object.minute * 60 + end_time_object.second
#      25 # convert the 'time' column from string to float
# ---> 26 transcripts_df['second'] = transcripts_df['second'].astype(float)
#      28 # select the rows with time between start_time and end_time, and concatenate the text values
#      29 selected_text = transcripts_df.loc[(transcripts_df['second'] >= start_time_seconds) & (transcripts_df['second'] <= end_time_seconds), 'text'].str.cat(sep=' ')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:138, in _astype_nansafe(arr, dtype, copy, skipna)
#     134     raise ValueError(msg)
#     136 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     137     # Explicit copy, or required since NumPy can't view from / to object.
# --> 138     return arr.astype(dtype, copy=True)
#     140 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'the'

# %%
## Save the aggregated dataset as a csv file
dataset.to_csv('Dataset/Aggregated Dataset/Episode_5.csv', index=False, columns=['time', 'chapter', 'transcript'])
